# %%
import torch
from torch import nn as nn
from torch.nn import functional as F
from torch.optim import Adam, SGD
import numpy as np

# %%
class NAC(nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
        self.W_hat = nn.Parameter(torch.Tensor(self.out_dim, self.in_dim))
        self.M_hat = nn.Parameter(torch.Tensor(self.out_dim, self.in_dim))
        nn.init.xavier_normal_(self.W_hat)
        nn.init.xavier_normal_(self.M_hat)
        self.bias = None
        
    def forward(self, x):
        W = torch.tanh(self.W_hat) * torch.sigmoid(self.M_hat)
        return F.linear(x, W, self.bias)

# %%
class NALU(nn.Module):
    def __init__(self, in_dim, out_dim):
        super().__init__()
        self.in_dim = in_dim
        self.out_dim = out_dim
#         self.G = nn.Linear(self.in_dim,
#                            self.out_dim,
#                            bias=False)
        self.G = nn.Parameter(torch.Tensor(1, 1))
        nn.init.xavier_normal_(self.G)
        self.nac = NAC(self.in_dim, self.out_dim)
        self.eps = 1e-10

    def forward(self, x):
        a = self.nac(x)
        g = torch.sigmoid(self.G)
        m = self.nac(torch.log(torch.abs(x) + self.eps))
        m = torch.exp(m)
        y = (g * a) + (1 - g) * m
        return y

# %%
eps = 1e-12
X_train = np.random.uniform(-5, 5+eps, size=(2000, 2))
Y_train = X_train[:, 0] * X_train[:, 1]

X_valid = np.random.uniform(-5, 5+eps, size=(500, 2))
Y_valid = X_valid[:, 0] * X_valid[:, 1]

X_test = np.random.uniform(-50, 50+eps, size=(2000, 2))
Y_test = X_test[:, 0] * X_test[:, 1]

# %%
def get_batches(data, target, batch_size, mode='test', use_gpu=False):
    idx = np.arange(0, data.shape[0])
    
    if mode == 'train':
        np.random.shuffle(idx)

    while idx.shape[0] > 0:
        batch_idx = idx[:batch_size]
        idx = idx[batch_size:]
        batch_data = data[batch_idx]
        batch_target = target[batch_idx]
        
        batch_data = torch.from_numpy(batch_data).float()
        batch_target = torch.from_numpy(batch_target).float().view(-1, 1)
        
        if use_gpu:
            batch_data = batch_data.cuda()
            batch_target = batch_target.cuda()
        
        yield batch_data, batch_target

# %%
def get_eval_loss(model, criterion, data, targets, use_gpu=False):
    preds, targets = get_eval_preds(model, data, targets, use_gpu)
    loss = criterion(preds, targets)
    return loss.item()

# %%
def get_eval_preds(model, data, targets, use_gpu=False):
    with torch.no_grad():
        model.eval()
        model_preds = []
        tensor_targets = []
        for x, y in get_batches(data, targets, batch_size,
                                mode='test', use_gpu=use_gpu):
            model_preds.append(model(x))
            tensor_targets.append(y)
        model_preds = torch.cat(model_preds, dim=0)
        tensor_targets = torch.cat(tensor_targets, dim=0)
    return model_preds, tensor_targets

# %%
batch_size = 32
patience = 15
running_patience = 5
checkpoint = 'best_model.sav'
print_every = 200
num_epochs = 5000
running_batch = 0
running_loss = 0
min_loss = float('inf')
use_gpu = torch.cuda.is_available()

criterion = nn.SmoothL1Loss()

model = NALU(2, 1)
if use_gpu:
    model = model.cuda()
optimizer = Adam(model.parameters())

for epoch in range(num_epochs):
    model.train()
    for x, y in get_batches(X_train, Y_train, batch_size,
                            mode='train', use_gpu=use_gpu):
        output = model(x)
        loss = criterion(output, y)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        running_batch += 1
        
#         if running_batch % print_every == 0:
#             print('Training loss after {} batches: {}'.format(running_batch, running_loss/running_batch))
            
    valid_loss = get_eval_loss(model, criterion,
                              X_valid, Y_valid, False)
    print("Validation loss after epoch {}: {}".format(epoch, valid_loss))
    if valid_loss < min_loss:
        min_loss = valid_loss
        print('Validation loss improved! Saving model.')
        with open(checkpoint, 'wb') as f:
            torch.save(model.state_dict(), f)
            running_patience = patience
    else:
        running_patience -= 1
    if running_patience == 0:
        print('Ran out of patience, early stopping employed!')
        break
# Out:
# Validation loss after epoch 0: 5.665528774261475
# Validation loss improved! Saving model.
# Validation loss after epoch 1: 5.657806873321533
# Validation loss improved! Saving model.
# Validation loss after epoch 2: 5.647764682769775
# Validation loss improved! Saving model.
# Validation loss after epoch 3: 5.636740207672119
# Validation loss improved! Saving model.
# Validation loss after epoch 4: 5.6271867752075195
# Validation loss improved! Saving model.
# Validation loss after epoch 5: 5.620261192321777
# Validation loss improved! Saving model.
# Validation loss after epoch 6: 5.614684104919434
# Validation loss improved! Saving model.
# Validation loss after epoch 7: 5.610252857208252
# Validation loss improved! Saving model.
# Validation loss after epoch 8: 5.606377124786377
# Validation loss improved! Saving model.
# Validation loss after epoch 9: 5.602868556976318
# Validation loss improved! Saving model.
# Validation loss after epoch 10: 5.599340438842773
# Validation loss improved! Saving model.
# Validation loss after epoch 11: 5.59574556350708
# Validation loss improved! Saving model.
# Validation loss after epoch 12: 5.5921220779418945
# Validation loss improved! Saving model.
# Validation loss after epoch 13: 5.588118076324463
# Validation loss improved! Saving model.
# Validation loss after epoch 14: 5.584045886993408
# Validation loss improved! Saving model.
# Validation loss after epoch 15: 5.579610824584961
# Validation loss improved! Saving model.
# Validation loss after epoch 16: 5.574808120727539
# Validation loss improved! Saving model.
# Validation loss after epoch 17: 5.569760322570801
# Validation loss improved! Saving model.
# Validation loss after epoch 18: 5.564275741577148
# Validation loss improved! Saving model.
# Validation loss after epoch 19: 5.5583906173706055
# Validation loss improved! Saving model.
# Validation loss after epoch 20: 5.551766395568848
# Validation loss improved! Saving model.
# Validation loss after epoch 21: 5.54453182220459
# Validation loss improved! Saving model.
# Validation loss after epoch 22: 5.536474704742432
# Validation loss improved! Saving model.
# Validation loss after epoch 23: 5.52785062789917
# Validation loss improved! Saving model.
# Validation loss after epoch 24: 5.518019676208496
# Validation loss improved! Saving model.
# Validation loss after epoch 25: 5.50655460357666
# Validation loss improved! Saving model.
# Validation loss after epoch 26: 5.493993759155273
# Validation loss improved! Saving model.
# Validation loss after epoch 27: 5.480256080627441
# Validation loss improved! Saving model.
# Validation loss after epoch 28: 5.463913917541504
# Validation loss improved! Saving model.
# Validation loss after epoch 29: 5.445742607116699
# Validation loss improved! Saving model.
# Validation loss after epoch 30: 5.4256744384765625
# Validation loss improved! Saving model.
# Validation loss after epoch 31: 5.4030561447143555
# Validation loss improved! Saving model.
# Validation loss after epoch 32: 5.378215312957764
# Validation loss improved! Saving model.
# Validation loss after epoch 33: 5.350823402404785
# Validation loss improved! Saving model.
# Validation loss after epoch 34: 5.321805477142334
# Validation loss improved! Saving model.
# Validation loss after epoch 35: 5.289495944976807
# Validation loss improved! Saving model.
# Validation loss after epoch 36: 5.254706859588623
# Validation loss improved! Saving model.
# Validation loss after epoch 37: 5.217400074005127
# Validation loss improved! Saving model.
# Validation loss after epoch 38: 5.177717685699463
# Validation loss improved! Saving model.
# Validation loss after epoch 39: 5.1329450607299805
# Validation loss improved! Saving model.
# Validation loss after epoch 40: 5.084505558013916
# Validation loss improved! Saving model.
# Validation loss after epoch 41: 5.030667781829834
# Validation loss improved! Saving model.
# Validation loss after epoch 42: 4.971592903137207
# Validation loss improved! Saving model.
# Validation loss after epoch 43: 4.9063720703125
# Validation loss improved! Saving model.
# Validation loss after epoch 44: 4.838253498077393
# Validation loss improved! Saving model.
# Validation loss after epoch 45: 4.769026756286621
# Validation loss improved! Saving model.
# Validation loss after epoch 46: 4.694572925567627
# Validation loss improved! Saving model.
# Validation loss after epoch 47: 4.620786666870117
# Validation loss improved! Saving model.
# Validation loss after epoch 48: 4.5473103523254395
# Validation loss improved! Saving model.
# Validation loss after epoch 49: 4.47178840637207
# Validation loss improved! Saving model.
# Validation loss after epoch 50: 4.401381492614746
# Validation loss improved! Saving model.
# Validation loss after epoch 51: 4.331704139709473
# Validation loss improved! Saving model.
# Validation loss after epoch 52: 4.263582706451416
# Validation loss improved! Saving model.
# Validation loss after epoch 53: 4.198293685913086
# Validation loss improved! Saving model.
# Validation loss after epoch 54: 4.138261795043945
# Validation loss improved! Saving model.
# Validation loss after epoch 55: 4.080512046813965
# Validation loss improved! Saving model.
# Validation loss after epoch 56: 4.022406101226807
# Validation loss improved! Saving model.
# Validation loss after epoch 57: 3.971965789794922
# Validation loss improved! Saving model.
# Validation loss after epoch 58: 3.921416759490967
# Validation loss improved! Saving model.
# Validation loss after epoch 59: 3.8755204677581787
# Validation loss improved! Saving model.
# Validation loss after epoch 60: 3.8307301998138428
# Validation loss improved! Saving model.
# Validation loss after epoch 61: 3.789003610610962
# Validation loss improved! Saving model.
# Validation loss after epoch 62: 3.749587297439575
# Validation loss improved! Saving model.
# Validation loss after epoch 63: 3.711611747741699
# Validation loss improved! Saving model.
# Validation loss after epoch 64: 3.6762044429779053
# Validation loss improved! Saving model.
# Validation loss after epoch 65: 3.64394211769104
# Validation loss improved! Saving model.
# Validation loss after epoch 66: 3.611776351928711
# Validation loss improved! Saving model.
# Validation loss after epoch 67: 3.5821900367736816
# Validation loss improved! Saving model.
# Validation loss after epoch 68: 3.554267406463623
# Validation loss improved! Saving model.
# Validation loss after epoch 69: 3.5279135704040527
# Validation loss improved! Saving model.
# Validation loss after epoch 70: 3.503152847290039
# Validation loss improved! Saving model.
# Validation loss after epoch 71: 3.479480504989624
# Validation loss improved! Saving model.
# Validation loss after epoch 72: 3.4571046829223633
# Validation loss improved! Saving model.
# Validation loss after epoch 73: 3.4359405040740967
# Validation loss improved! Saving model.
# Validation loss after epoch 74: 3.4161441326141357
# Validation loss improved! Saving model.
# Validation loss after epoch 75: 3.3969621658325195
# Validation loss improved! Saving model.
# Validation loss after epoch 76: 3.3786253929138184
# Validation loss improved! Saving model.
# Validation loss after epoch 77: 3.361521005630493
# Validation loss improved! Saving model.
# Validation loss after epoch 78: 3.3452839851379395
# Validation loss improved! Saving model.
# Validation loss after epoch 79: 3.3303141593933105
# Validation loss improved! Saving model.
# Validation loss after epoch 80: 3.3161678314208984
# Validation loss improved! Saving model.
# Validation loss after epoch 81: 3.3019917011260986
# Validation loss improved! Saving model.
# Validation loss after epoch 82: 3.288888454437256
# Validation loss improved! Saving model.
# Validation loss after epoch 83: 3.2762715816497803
# Validation loss improved! Saving model.
# Validation loss after epoch 84: 3.264279842376709
# Validation loss improved! Saving model.
# Validation loss after epoch 85: 3.2531347274780273
# Validation loss improved! Saving model.
# Validation loss after epoch 86: 3.242135524749756
# Validation loss improved! Saving model.
# Validation loss after epoch 87: 3.2322216033935547
# Validation loss improved! Saving model.
# Validation loss after epoch 88: 3.222348213195801
# Validation loss improved! Saving model.
# Validation loss after epoch 89: 3.212709665298462
# Validation loss improved! Saving model.
# Validation loss after epoch 90: 3.203801155090332
# Validation loss improved! Saving model.
# Validation loss after epoch 91: 3.195539712905884
# Validation loss improved! Saving model.
# Validation loss after epoch 92: 3.1872646808624268
# Validation loss improved! Saving model.
# Validation loss after epoch 93: 3.1794495582580566
# Validation loss improved! Saving model.
# Validation loss after epoch 94: 3.171966075897217
# Validation loss improved! Saving model.
# Validation loss after epoch 95: 3.1648077964782715
# Validation loss improved! Saving model.
# Validation loss after epoch 96: 3.158099412918091
# Validation loss improved! Saving model.
# Validation loss after epoch 97: 3.151664972305298
# Validation loss improved! Saving model.
# Validation loss after epoch 98: 3.1452035903930664
# Validation loss improved! Saving model.
# Validation loss after epoch 99: 3.1394567489624023
# Validation loss improved! Saving model.
# Validation loss after epoch 100: 3.133735418319702
# Validation loss improved! Saving model.
# Validation loss after epoch 101: 3.1280696392059326
# Validation loss improved! Saving model.
# Validation loss after epoch 102: 3.122917890548706
# Validation loss improved! Saving model.
# Validation loss after epoch 103: 3.1179428100585938
# Validation loss improved! Saving model.
# Validation loss after epoch 104: 3.113191843032837
# Validation loss improved! Saving model.
# Validation loss after epoch 105: 3.1086113452911377
# Validation loss improved! Saving model.
# Validation loss after epoch 106: 3.1041135787963867
# Validation loss improved! Saving model.
# Validation loss after epoch 107: 3.1000916957855225
# Validation loss improved! Saving model.
# Validation loss after epoch 108: 3.095811367034912
# Validation loss improved! Saving model.
# Validation loss after epoch 109: 3.092034339904785
# Validation loss improved! Saving model.
# Validation loss after epoch 110: 3.0882279872894287
# Validation loss improved! Saving model.
# Validation loss after epoch 111: 3.0845611095428467
# Validation loss improved! Saving model.
# Validation loss after epoch 112: 3.081254243850708
# Validation loss improved! Saving model.
# Validation loss after epoch 113: 3.0779190063476562
# Validation loss improved! Saving model.
# Validation loss after epoch 114: 3.074702739715576
# Validation loss improved! Saving model.
# Validation loss after epoch 115: 3.0718395709991455
# Validation loss improved! Saving model.
# Validation loss after epoch 116: 3.0688414573669434
# Validation loss improved! Saving model.
# Validation loss after epoch 117: 3.0660502910614014
# Validation loss improved! Saving model.
# Validation loss after epoch 118: 3.0633325576782227
# Validation loss improved! Saving model.
# Validation loss after epoch 119: 3.060774564743042
# Validation loss improved! Saving model.
# Validation loss after epoch 120: 3.058464288711548
# Validation loss improved! Saving model.
# Validation loss after epoch 121: 3.0560967922210693
# Validation loss improved! Saving model.
# Validation loss after epoch 122: 3.053724527359009
# Validation loss improved! Saving model.
# Validation loss after epoch 123: 3.0516200065612793
# Validation loss improved! Saving model.
# Validation loss after epoch 124: 3.0494256019592285
# Validation loss improved! Saving model.
# Validation loss after epoch 125: 3.047475576400757
# Validation loss improved! Saving model.
# Validation loss after epoch 126: 3.0455801486968994
# Validation loss improved! Saving model.
# Validation loss after epoch 127: 3.0435950756073
# Validation loss improved! Saving model.
# Validation loss after epoch 128: 3.0418901443481445
# Validation loss improved! Saving model.
# Validation loss after epoch 129: 3.0400843620300293
# Validation loss improved! Saving model.
# Validation loss after epoch 130: 3.038435220718384
# Validation loss improved! Saving model.
# Validation loss after epoch 131: 3.036795139312744
# Validation loss improved! Saving model.
# Validation loss after epoch 132: 3.035187244415283
# Validation loss improved! Saving model.
# Validation loss after epoch 133: 3.0337555408477783
# Validation loss improved! Saving model.
# Validation loss after epoch 134: 3.0322952270507812
# Validation loss improved! Saving model.
# Validation loss after epoch 135: 3.030923366546631
# Validation loss improved! Saving model.
# Validation loss after epoch 136: 3.0294713973999023
# Validation loss improved! Saving model.
# Validation loss after epoch 137: 3.0281739234924316
# Validation loss improved! Saving model.
# Validation loss after epoch 138: 3.02691912651062
# Validation loss improved! Saving model.
# Validation loss after epoch 139: 3.025662422180176
# Validation loss improved! Saving model.
# Validation loss after epoch 140: 3.024427890777588
# Validation loss improved! Saving model.
# Validation loss after epoch 141: 3.023261308670044
# Validation loss improved! Saving model.
# Validation loss after epoch 142: 3.022108793258667
# Validation loss improved! Saving model.
# Validation loss after epoch 143: 3.0210201740264893
# Validation loss improved! Saving model.
# Validation loss after epoch 144: 3.019944429397583
# Validation loss improved! Saving model.
# Validation loss after epoch 145: 3.0189273357391357
# Validation loss improved! Saving model.
# Validation loss after epoch 146: 3.0179007053375244
# Validation loss improved! Saving model.
# Validation loss after epoch 147: 3.0169386863708496
# Validation loss improved! Saving model.
# Validation loss after epoch 148: 3.0159449577331543
# Validation loss improved! Saving model.
# Validation loss after epoch 149: 3.0149879455566406
# Validation loss improved! Saving model.
# Validation loss after epoch 150: 3.014099359512329
# Validation loss improved! Saving model.
# Validation loss after epoch 151: 3.013150930404663
# Validation loss improved! Saving model.
# Validation loss after epoch 152: 3.0122814178466797
# Validation loss improved! Saving model.
# Validation loss after epoch 153: 3.011439323425293
# Validation loss improved! Saving model.
# Validation loss after epoch 154: 3.0106310844421387
# Validation loss improved! Saving model.
# Validation loss after epoch 155: 3.0097968578338623
# Validation loss improved! Saving model.
# Validation loss after epoch 156: 3.0089828968048096
# Validation loss improved! Saving model.
# Validation loss after epoch 157: 3.0081541538238525
# Validation loss improved! Saving model.
# Validation loss after epoch 158: 3.0074045658111572
# Validation loss improved! Saving model.
# Validation loss after epoch 159: 3.0066306591033936
# Validation loss improved! Saving model.
# Validation loss after epoch 160: 3.0059335231781006
# Validation loss improved! Saving model.
# Validation loss after epoch 161: 3.0051748752593994
# Validation loss improved! Saving model.
# Validation loss after epoch 162: 3.004469633102417
# Validation loss improved! Saving model.
# Validation loss after epoch 163: 3.003777265548706
# Validation loss improved! Saving model.
# Validation loss after epoch 164: 3.0030269622802734
# Validation loss improved! Saving model.
# Validation loss after epoch 165: 3.0023977756500244
# Validation loss improved! Saving model.
# Validation loss after epoch 166: 3.0017290115356445
# Validation loss improved! Saving model.
# Validation loss after epoch 167: 3.0010948181152344
# Validation loss improved! Saving model.
# Validation loss after epoch 168: 3.0004167556762695
# Validation loss improved! Saving model.
# Validation loss after epoch 169: 2.9997947216033936
# Validation loss improved! Saving model.
# Validation loss after epoch 170: 2.9992032051086426
# Validation loss improved! Saving model.
# Validation loss after epoch 171: 2.9985690116882324
# Validation loss improved! Saving model.
# Validation loss after epoch 172: 2.9980030059814453
# Validation loss improved! Saving model.
# Validation loss after epoch 173: 2.99735689163208
# Validation loss improved! Saving model.
# Validation loss after epoch 174: 2.996778726577759
# Validation loss improved! Saving model.
# Validation loss after epoch 175: 2.9962265491485596
# Validation loss improved! Saving model.
# Validation loss after epoch 176: 2.9956674575805664
# Validation loss improved! Saving model.
# Validation loss after epoch 177: 2.995095729827881
# Validation loss improved! Saving model.
# Validation loss after epoch 178: 2.994563579559326
# Validation loss improved! Saving model.
# Validation loss after epoch 179: 2.994041681289673
# Validation loss improved! Saving model.
# Validation loss after epoch 180: 2.9935200214385986
# Validation loss improved! Saving model.
# Validation loss after epoch 181: 2.9930026531219482
# Validation loss improved! Saving model.
# Validation loss after epoch 182: 2.992462635040283
# Validation loss improved! Saving model.
# Validation loss after epoch 183: 2.9919817447662354
# Validation loss improved! Saving model.
# Validation loss after epoch 184: 2.9914612770080566
# Validation loss improved! Saving model.
# Validation loss after epoch 185: 2.990964412689209
# Validation loss improved! Saving model.
# Validation loss after epoch 186: 2.990417957305908
# Validation loss improved! Saving model.
# Validation loss after epoch 187: 2.989988088607788
# Validation loss improved! Saving model.
# Validation loss after epoch 188: 2.989508628845215
# Validation loss improved! Saving model.
# Validation loss after epoch 189: 2.9890151023864746
# Validation loss improved! Saving model.
# Validation loss after epoch 190: 2.9885690212249756
# Validation loss improved! Saving model.
# Validation loss after epoch 191: 2.9880945682525635
# Validation loss improved! Saving model.
# Validation loss after epoch 192: 2.987632989883423
# Validation loss improved! Saving model.
# Validation loss after epoch 193: 2.987166404724121
# Validation loss improved! Saving model.
# Validation loss after epoch 194: 2.9866912364959717
# Validation loss improved! Saving model.
# Validation loss after epoch 195: 2.9862728118896484
# Validation loss improved! Saving model.
# Validation loss after epoch 196: 2.985854387283325
# Validation loss improved! Saving model.
# Validation loss after epoch 197: 2.9854116439819336
# Validation loss improved! Saving model.
# Validation loss after epoch 198: 2.9849588871002197
# Validation loss improved! Saving model.
# Validation loss after epoch 199: 2.984551429748535
# Validation loss improved! Saving model.
# Validation loss after epoch 200: 2.9841599464416504
# Validation loss improved! Saving model.
# Validation loss after epoch 201: 2.9837088584899902
# Validation loss improved! Saving model.
# Validation loss after epoch 202: 2.983288049697876
# Validation loss improved! Saving model.
# Validation loss after epoch 203: 2.9829084873199463
# Validation loss improved! Saving model.
# Validation loss after epoch 204: 2.982468366622925
# Validation loss improved! Saving model.
# Validation loss after epoch 205: 2.982130289077759
# Validation loss improved! Saving model.
# Validation loss after epoch 206: 2.981735944747925
# Validation loss improved! Saving model.
# Validation loss after epoch 207: 2.981349229812622
# Validation loss improved! Saving model.
# Validation loss after epoch 208: 2.9808995723724365
# Validation loss improved! Saving model.
# Validation loss after epoch 209: 2.980532169342041
# Validation loss improved! Saving model.
# Validation loss after epoch 210: 2.98013973236084
# Validation loss improved! Saving model.
# Validation loss after epoch 211: 2.9797677993774414
# Validation loss improved! Saving model.
# Validation loss after epoch 212: 2.979357957839966
# Validation loss improved! Saving model.
# Validation loss after epoch 213: 2.978964328765869
# Validation loss improved! Saving model.
# Validation loss after epoch 214: 2.978616714477539
# Validation loss improved! Saving model.
# Validation loss after epoch 215: 2.9781997203826904
# Validation loss improved! Saving model.
# Validation loss after epoch 216: 2.977830410003662
# Validation loss improved! Saving model.
# Validation loss after epoch 217: 2.977492094039917
# Validation loss improved! Saving model.
# Validation loss after epoch 218: 2.9771275520324707
# Validation loss improved! Saving model.
# Validation loss after epoch 219: 2.9768564701080322
# Validation loss improved! Saving model.
# Validation loss after epoch 220: 2.97636342048645
# Validation loss improved! Saving model.
# Validation loss after epoch 221: 2.9760308265686035
# Validation loss improved! Saving model.
# Validation loss after epoch 222: 2.975841760635376
# Validation loss improved! Saving model.
# Validation loss after epoch 223: 2.9753196239471436
# Validation loss improved! Saving model.
# Validation loss after epoch 224: 2.9749042987823486
# Validation loss improved! Saving model.
# Validation loss after epoch 225: 2.974590301513672
# Validation loss improved! Saving model.
# Validation loss after epoch 226: 2.974299669265747
# Validation loss improved! Saving model.
# Validation loss after epoch 227: 2.973984479904175
# Validation loss improved! Saving model.
# Validation loss after epoch 228: 2.9735991954803467
# Validation loss improved! Saving model.
# Validation loss after epoch 229: 2.9732115268707275
# Validation loss improved! Saving model.
# Validation loss after epoch 230: 2.972914457321167
# Validation loss improved! Saving model.
# Validation loss after epoch 231: 2.972503185272217
# Validation loss improved! Saving model.
# Validation loss after epoch 232: 2.9722647666931152
# Validation loss improved! Saving model.
# Validation loss after epoch 233: 2.971885919570923
# Validation loss improved! Saving model.
# Validation loss after epoch 234: 2.9715278148651123
# Validation loss improved! Saving model.
# Validation loss after epoch 235: 2.971194267272949
# Validation loss improved! Saving model.
# Validation loss after epoch 236: 2.9708871841430664
# Validation loss improved! Saving model.
# Validation loss after epoch 237: 2.9705207347869873
# Validation loss improved! Saving model.
# Validation loss after epoch 238: 2.9703075885772705
# Validation loss improved! Saving model.
# Validation loss after epoch 239: 2.9698486328125
# Validation loss improved! Saving model.
# Validation loss after epoch 240: 2.969573497772217
# Validation loss improved! Saving model.
# Validation loss after epoch 241: 2.969297409057617
# Validation loss improved! Saving model.
# Validation loss after epoch 242: 2.9689137935638428
# Validation loss improved! Saving model.
# Validation loss after epoch 243: 2.968580722808838
# Validation loss improved! Saving model.
# Validation loss after epoch 244: 2.968289375305176
# Validation loss improved! Saving model.
# Validation loss after epoch 245: 2.967965841293335
# Validation loss improved! Saving model.
# Validation loss after epoch 246: 2.9676613807678223
# Validation loss improved! Saving model.
# Validation loss after epoch 247: 2.9673547744750977
# Validation loss improved! Saving model.
# Validation loss after epoch 248: 2.967071294784546
# Validation loss improved! Saving model.
# Validation loss after epoch 249: 2.9667277336120605
# Validation loss improved! Saving model.
# Validation loss after epoch 250: 2.9664013385772705
# Validation loss improved! Saving model.
# Validation loss after epoch 251: 2.966053009033203
# Validation loss improved! Saving model.
# Validation loss after epoch 252: 2.965869426727295
# Validation loss improved! Saving model.
# Validation loss after epoch 253: 2.9654033184051514
# Validation loss improved! Saving model.
# Validation loss after epoch 254: 2.965129852294922
# Validation loss improved! Saving model.
# Validation loss after epoch 255: 2.9648022651672363
# Validation loss improved! Saving model.
# Validation loss after epoch 256: 2.9646568298339844
# Validation loss improved! Saving model.
# Validation loss after epoch 257: 2.964015007019043
# Validation loss improved! Saving model.
# Validation loss after epoch 258: 2.9637608528137207
# Validation loss improved! Saving model.
# Validation loss after epoch 259: 2.9634931087493896
# Validation loss improved! Saving model.
# Validation loss after epoch 260: 2.963197946548462
# Validation loss improved! Saving model.
# Validation loss after epoch 261: 2.9629366397857666
# Validation loss improved! Saving model.
# Validation loss after epoch 262: 2.9626379013061523
# Validation loss improved! Saving model.
# Validation loss after epoch 263: 2.9623875617980957
# Validation loss improved! Saving model.
# Validation loss after epoch 264: 2.962231159210205
# Validation loss improved! Saving model.
# Validation loss after epoch 265: 2.961681604385376
# Validation loss improved! Saving model.
# Validation loss after epoch 266: 2.961353302001953
# Validation loss improved! Saving model.
# Validation loss after epoch 267: 2.961186170578003
# Validation loss improved! Saving model.
# Validation loss after epoch 268: 2.960949182510376
# Validation loss improved! Saving model.
# Validation loss after epoch 269: 2.9606149196624756
# Validation loss improved! Saving model.
# Validation loss after epoch 270: 2.960348606109619
# Validation loss improved! Saving model.
# Validation loss after epoch 271: 2.96008038520813
# Validation loss improved! Saving model.
# Validation loss after epoch 272: 2.9598751068115234
# Validation loss improved! Saving model.
# Validation loss after epoch 273: 2.9595742225646973
# Validation loss improved! Saving model.
# Validation loss after epoch 274: 2.9594500064849854
# Validation loss improved! Saving model.
# Validation loss after epoch 275: 2.9589006900787354
# Validation loss improved! Saving model.
# Validation loss after epoch 276: 2.9587242603302
# Validation loss improved! Saving model.
# Validation loss after epoch 277: 2.9584858417510986
# Validation loss improved! Saving model.
# Validation loss after epoch 278: 2.9583818912506104
# Validation loss improved! Saving model.
# Validation loss after epoch 279: 2.958021640777588
# Validation loss improved! Saving model.
# Validation loss after epoch 280: 2.9576172828674316
# Validation loss improved! Saving model.
# Validation loss after epoch 281: 2.9574856758117676
# Validation loss improved! Saving model.
# Validation loss after epoch 282: 2.9571480751037598
# Validation loss improved! Saving model.
# Validation loss after epoch 283: 2.9568674564361572
# Validation loss improved! Saving model.
# Validation loss after epoch 284: 2.9566686153411865
# Validation loss improved! Saving model.
# Validation loss after epoch 285: 2.9563510417938232
# Validation loss improved! Saving model.
# Validation loss after epoch 286: 2.956148624420166
# Validation loss improved! Saving model.
# Validation loss after epoch 287: 2.955791711807251
# Validation loss improved! Saving model.
# Validation loss after epoch 288: 2.955523729324341
# Validation loss improved! Saving model.
# Validation loss after epoch 289: 2.955298900604248
# Validation loss improved! Saving model.
# Validation loss after epoch 290: 2.955153465270996
# Validation loss improved! Saving model.
# Validation loss after epoch 291: 2.9546337127685547
# Validation loss improved! Saving model.
# Validation loss after epoch 292: 2.9544055461883545
# Validation loss improved! Saving model.
# Validation loss after epoch 293: 2.954474449157715
# Validation loss after epoch 294: 2.9539716243743896
# Validation loss improved! Saving model.
# Validation loss after epoch 295: 2.953747510910034
# Validation loss improved! Saving model.
# Validation loss after epoch 296: 2.9534642696380615
# Validation loss improved! Saving model.
# Validation loss after epoch 297: 2.953160285949707
# Validation loss improved! Saving model.
# Validation loss after epoch 298: 2.9528610706329346
# Validation loss improved! Saving model.
# Validation loss after epoch 299: 2.9527058601379395
# Validation loss improved! Saving model.
# Validation loss after epoch 300: 2.952515125274658
# Validation loss improved! Saving model.
# Validation loss after epoch 301: 2.9523019790649414
# Validation loss improved! Saving model.
# Validation loss after epoch 302: 2.9519360065460205
# Validation loss improved! Saving model.
# Validation loss after epoch 303: 2.951753616333008
# Validation loss improved! Saving model.
# Validation loss after epoch 304: 2.9514646530151367
# Validation loss improved! Saving model.
# Validation loss after epoch 305: 2.951249599456787
# Validation loss improved! Saving model.
# Validation loss after epoch 306: 2.9509613513946533
# Validation loss improved! Saving model.
# Validation loss after epoch 307: 2.9507689476013184
# Validation loss improved! Saving model.
# Validation loss after epoch 308: 2.95044207572937
# Validation loss improved! Saving model.
# Validation loss after epoch 309: 2.9502172470092773
# Validation loss improved! Saving model.
# Validation loss after epoch 310: 2.9499428272247314
# Validation loss improved! Saving model.
# Validation loss after epoch 311: 2.9497814178466797
# Validation loss improved! Saving model.
# Validation loss after epoch 312: 2.9495182037353516
# Validation loss improved! Saving model.
# Validation loss after epoch 313: 2.949215888977051
# Validation loss improved! Saving model.
# Validation loss after epoch 314: 2.9491894245147705
# Validation loss improved! Saving model.
# Validation loss after epoch 315: 2.948868989944458
# Validation loss improved! Saving model.
# Validation loss after epoch 316: 2.9486138820648193
# Validation loss improved! Saving model.
# Validation loss after epoch 317: 2.9485080242156982
# Validation loss improved! Saving model.
# Validation loss after epoch 318: 2.9482126235961914
# Validation loss improved! Saving model.
# Validation loss after epoch 319: 2.9479711055755615
# Validation loss improved! Saving model.
# Validation loss after epoch 320: 2.9476094245910645
# Validation loss improved! Saving model.
# Validation loss after epoch 321: 2.9475841522216797
# Validation loss improved! Saving model.
# Validation loss after epoch 322: 2.9472901821136475
# Validation loss improved! Saving model.
# Validation loss after epoch 323: 2.9469106197357178
# Validation loss improved! Saving model.
# Validation loss after epoch 324: 2.946685314178467
# Validation loss improved! Saving model.
# Validation loss after epoch 325: 2.946415662765503
# Validation loss improved! Saving model.
# Validation loss after epoch 326: 2.946176052093506
# Validation loss improved! Saving model.
# Validation loss after epoch 327: 2.945941209793091
# Validation loss improved! Saving model.
# Validation loss after epoch 328: 2.945744514465332
# Validation loss improved! Saving model.
# Validation loss after epoch 329: 2.945568084716797
# Validation loss improved! Saving model.
# Validation loss after epoch 330: 2.9453134536743164
# Validation loss improved! Saving model.
# Validation loss after epoch 331: 2.9450879096984863
# Validation loss improved! Saving model.
# Validation loss after epoch 332: 2.9450223445892334
# Validation loss improved! Saving model.
# Validation loss after epoch 333: 2.9445714950561523
# Validation loss improved! Saving model.
# Validation loss after epoch 334: 2.9443352222442627
# Validation loss improved! Saving model.
# Validation loss after epoch 335: 2.94427227973938
# Validation loss improved! Saving model.
# Validation loss after epoch 336: 2.944014549255371
# Validation loss improved! Saving model.
# Validation loss after epoch 337: 2.9436635971069336
# Validation loss improved! Saving model.
# Validation loss after epoch 338: 2.9435741901397705
# Validation loss improved! Saving model.
# Validation loss after epoch 339: 2.9433162212371826
# Validation loss improved! Saving model.
# Validation loss after epoch 340: 2.9429430961608887
# Validation loss improved! Saving model.
# Validation loss after epoch 341: 2.9428350925445557
# Validation loss improved! Saving model.
# Validation loss after epoch 342: 2.9425926208496094
# Validation loss improved! Saving model.
# Validation loss after epoch 343: 2.9425275325775146
# Validation loss improved! Saving model.
# Validation loss after epoch 344: 2.9421427249908447
# Validation loss improved! Saving model.
# Validation loss after epoch 345: 2.942049026489258
# Validation loss improved! Saving model.
# Validation loss after epoch 346: 2.9417357444763184
# Validation loss improved! Saving model.
# Validation loss after epoch 347: 2.94146466255188
# Validation loss improved! Saving model.
# Validation loss after epoch 348: 2.9412729740142822
# Validation loss improved! Saving model.
# Validation loss after epoch 349: 2.941124200820923
# Validation loss improved! Saving model.
# Validation loss after epoch 350: 2.9406886100769043
# Validation loss improved! Saving model.
# Validation loss after epoch 351: 2.940678596496582
# Validation loss improved! Saving model.
# Validation loss after epoch 352: 2.940448522567749
# Validation loss improved! Saving model.
# Validation loss after epoch 353: 2.9404993057250977
# Validation loss after epoch 354: 2.9400408267974854
# Validation loss improved! Saving model.
# Validation loss after epoch 355: 2.939851760864258
# Validation loss improved! Saving model.
# Validation loss after epoch 356: 2.9395744800567627
# Validation loss improved! Saving model.
# Validation loss after epoch 357: 2.939419746398926
# Validation loss improved! Saving model.
# Validation loss after epoch 358: 2.939356803894043
# Validation loss improved! Saving model.
# Validation loss after epoch 359: 2.9389901161193848
# Validation loss improved! Saving model.
# Validation loss after epoch 360: 2.938890218734741
# Validation loss improved! Saving model.
# Validation loss after epoch 361: 2.9387283325195312
# Validation loss improved! Saving model.
# Validation loss after epoch 362: 2.938508987426758
# Validation loss improved! Saving model.
# Validation loss after epoch 363: 2.938249349594116
# Validation loss improved! Saving model.
# Validation loss after epoch 364: 2.9379193782806396
# Validation loss improved! Saving model.
# Validation loss after epoch 365: 2.937957286834717
# Validation loss after epoch 366: 2.9376556873321533
# Validation loss improved! Saving model.
# Validation loss after epoch 367: 2.9373605251312256
# Validation loss improved! Saving model.
# Validation loss after epoch 368: 2.937228202819824
# Validation loss improved! Saving model.
# Validation loss after epoch 369: 2.9371259212493896
# Validation loss improved! Saving model.
# Validation loss after epoch 370: 2.936882495880127
# Validation loss improved! Saving model.
# Validation loss after epoch 371: 2.936656951904297
# Validation loss improved! Saving model.
# Validation loss after epoch 372: 2.936566114425659
# Validation loss improved! Saving model.
# Validation loss after epoch 373: 2.9364707469940186
# Validation loss improved! Saving model.
# Validation loss after epoch 374: 2.936011552810669
# Validation loss improved! Saving model.
# Validation loss after epoch 375: 2.9358279705047607
# Validation loss improved! Saving model.
# Validation loss after epoch 376: 2.9356322288513184
# Validation loss improved! Saving model.
# Validation loss after epoch 377: 2.9357028007507324
# Validation loss after epoch 378: 2.9353420734405518
# Validation loss improved! Saving model.
# Validation loss after epoch 379: 2.9351282119750977
# Validation loss improved! Saving model.
# Validation loss after epoch 380: 2.9350035190582275
# Validation loss improved! Saving model.
# Validation loss after epoch 381: 2.9347519874572754
# Validation loss improved! Saving model.
# Validation loss after epoch 382: 2.934574842453003
# Validation loss improved! Saving model.
# Validation loss after epoch 383: 2.934455156326294
# Validation loss improved! Saving model.
# Validation loss after epoch 384: 2.9343090057373047
# Validation loss improved! Saving model.
# Validation loss after epoch 385: 2.9340195655822754
# Validation loss improved! Saving model.
# Validation loss after epoch 386: 2.9338901042938232
# Validation loss improved! Saving model.
# Validation loss after epoch 387: 2.933795213699341
# Validation loss improved! Saving model.
# Validation loss after epoch 388: 2.933490514755249
# Validation loss improved! Saving model.
# Validation loss after epoch 389: 2.9332897663116455
# Validation loss improved! Saving model.
# Validation loss after epoch 390: 2.933128833770752
# Validation loss improved! Saving model.
# Validation loss after epoch 391: 2.932934045791626
# Validation loss improved! Saving model.
# Validation loss after epoch 392: 2.9328110218048096
# Validation loss improved! Saving model.
# Validation loss after epoch 393: 2.932659387588501
# Validation loss improved! Saving model.
# Validation loss after epoch 394: 2.932460069656372
# Validation loss improved! Saving model.
# Validation loss after epoch 395: 2.932344913482666
# Validation loss improved! Saving model.
# Validation loss after epoch 396: 2.9321694374084473
# Validation loss improved! Saving model.
# Validation loss after epoch 397: 2.9319844245910645
# Validation loss improved! Saving model.
# Validation loss after epoch 398: 2.931913137435913
# Validation loss improved! Saving model.
# Validation loss after epoch 399: 2.931636333465576
# Validation loss improved! Saving model.
# Validation loss after epoch 400: 2.9314115047454834
# Validation loss improved! Saving model.
# Validation loss after epoch 401: 2.931224822998047
# Validation loss improved! Saving model.
# Validation loss after epoch 402: 2.9311845302581787
# Validation loss improved! Saving model.
# Validation loss after epoch 403: 2.9309747219085693
# Validation loss improved! Saving model.
# Validation loss after epoch 404: 2.9306795597076416
# Validation loss improved! Saving model.
# Validation loss after epoch 405: 2.9307477474212646
# Validation loss after epoch 406: 2.9303300380706787
# Validation loss improved! Saving model.
# Validation loss after epoch 407: 2.9302380084991455
# Validation loss improved! Saving model.
# Validation loss after epoch 408: 2.9301037788391113
# Validation loss improved! Saving model.
# Validation loss after epoch 409: 2.9299323558807373
# Validation loss improved! Saving model.
# Validation loss after epoch 410: 2.930020332336426
# Validation loss after epoch 411: 2.9295594692230225
# Validation loss improved! Saving model.
# Validation loss after epoch 412: 2.929323196411133
# Validation loss improved! Saving model.
# Validation loss after epoch 413: 2.929211378097534
# Validation loss improved! Saving model.
# Validation loss after epoch 414: 2.9290354251861572
# Validation loss improved! Saving model.
# Validation loss after epoch 415: 2.9290499687194824
# Validation loss after epoch 416: 2.9287877082824707
# Validation loss improved! Saving model.
# Validation loss after epoch 417: 2.9286859035491943
# Validation loss improved! Saving model.
# Validation loss after epoch 418: 2.9285175800323486
# Validation loss improved! Saving model.
# Validation loss after epoch 419: 2.9282913208007812
# Validation loss improved! Saving model.
# Validation loss after epoch 420: 2.9282495975494385
# Validation loss improved! Saving model.
# Validation loss after epoch 421: 2.927980661392212
# Validation loss improved! Saving model.
# Validation loss after epoch 422: 2.9278564453125
# Validation loss improved! Saving model.
# Validation loss after epoch 423: 2.927727460861206
# Validation loss improved! Saving model.
# Validation loss after epoch 424: 2.927823543548584
# Validation loss after epoch 425: 2.927466630935669
# Validation loss improved! Saving model.
# Validation loss after epoch 426: 2.92736554145813
# Validation loss improved! Saving model.
# Validation loss after epoch 427: 2.927082061767578
# Validation loss improved! Saving model.
# Validation loss after epoch 428: 2.9270310401916504
# Validation loss improved! Saving model.
# Validation loss after epoch 429: 2.926841974258423
# Validation loss improved! Saving model.
# Validation loss after epoch 430: 2.9267477989196777
# Validation loss improved! Saving model.
# Validation loss after epoch 431: 2.926367998123169
# Validation loss improved! Saving model.
# Validation loss after epoch 432: 2.9263086318969727
# Validation loss improved! Saving model.
# Validation loss after epoch 433: 2.926218271255493
# Validation loss improved! Saving model.
# Validation loss after epoch 434: 2.9261882305145264
# Validation loss improved! Saving model.
# Validation loss after epoch 435: 2.925795793533325
# Validation loss improved! Saving model.
# Validation loss after epoch 436: 2.925590753555298
# Validation loss improved! Saving model.
# Validation loss after epoch 437: 2.925554037094116
# Validation loss improved! Saving model.
# Validation loss after epoch 438: 2.9255173206329346
# Validation loss improved! Saving model.
# Validation loss after epoch 439: 2.925213575363159
# Validation loss improved! Saving model.
# Validation loss after epoch 440: 2.9251911640167236
# Validation loss improved! Saving model.
# Validation loss after epoch 441: 2.9249813556671143
# Validation loss improved! Saving model.
# Validation loss after epoch 442: 2.924805164337158
# Validation loss improved! Saving model.
# Validation loss after epoch 443: 2.9247071743011475
# Validation loss improved! Saving model.
# Validation loss after epoch 444: 2.9247093200683594
# Validation loss after epoch 445: 2.9244251251220703
# Validation loss improved! Saving model.
# Validation loss after epoch 446: 2.9243009090423584
# Validation loss improved! Saving model.
# Validation loss after epoch 447: 2.9243850708007812
# Validation loss after epoch 448: 2.9241373538970947
# Validation loss improved! Saving model.
# Validation loss after epoch 449: 2.9238803386688232
# Validation loss improved! Saving model.
# Validation loss after epoch 450: 2.923647165298462
# Validation loss improved! Saving model.
# Validation loss after epoch 451: 2.923642873764038
# Validation loss improved! Saving model.
# Validation loss after epoch 452: 2.9233410358428955
# Validation loss improved! Saving model.
# Validation loss after epoch 453: 2.923265218734741
# Validation loss improved! Saving model.
# Validation loss after epoch 454: 2.923199415206909
# Validation loss improved! Saving model.
# Validation loss after epoch 455: 2.922896385192871
# Validation loss improved! Saving model.
# Validation loss after epoch 456: 2.9227797985076904
# Validation loss improved! Saving model.
# Validation loss after epoch 457: 2.922682523727417
# Validation loss improved! Saving model.
# Validation loss after epoch 458: 2.922729730606079
# Validation loss after epoch 459: 2.922478675842285
# Validation loss improved! Saving model.
# Validation loss after epoch 460: 2.92217755317688
# Validation loss improved! Saving model.
# Validation loss after epoch 461: 2.9222161769866943
# Validation loss after epoch 462: 2.9221203327178955
# Validation loss improved! Saving model.
# Validation loss after epoch 463: 2.9218852519989014
# Validation loss improved! Saving model.
# Validation loss after epoch 464: 2.921745777130127
# Validation loss improved! Saving model.
# Validation loss after epoch 465: 2.9218156337738037
# Validation loss after epoch 466: 2.9214107990264893
# Validation loss improved! Saving model.
# Validation loss after epoch 467: 2.9214680194854736
# Validation loss after epoch 468: 2.921506404876709
# Validation loss after epoch 469: 2.9213738441467285
# Validation loss improved! Saving model.
# Validation loss after epoch 470: 2.920971155166626
# Validation loss improved! Saving model.
# Validation loss after epoch 471: 2.9210119247436523
# Validation loss after epoch 472: 2.9207053184509277
# Validation loss improved! Saving model.
# Validation loss after epoch 473: 2.9206840991973877
# Validation loss improved! Saving model.
# Validation loss after epoch 474: 2.920510768890381
# Validation loss improved! Saving model.
# Validation loss after epoch 475: 2.920426368713379
# Validation loss improved! Saving model.
# Validation loss after epoch 476: 2.9200470447540283
# Validation loss improved! Saving model.
# Validation loss after epoch 477: 2.9199106693267822
# Validation loss improved! Saving model.
# Validation loss after epoch 478: 2.9198365211486816
# Validation loss improved! Saving model.
# Validation loss after epoch 479: 2.919720411300659
# Validation loss improved! Saving model.
# Validation loss after epoch 480: 2.9197707176208496
# Validation loss after epoch 481: 2.9194912910461426
# Validation loss improved! Saving model.
# Validation loss after epoch 482: 2.919328212738037
# Validation loss improved! Saving model.
# Validation loss after epoch 483: 2.919205665588379
# Validation loss improved! Saving model.
# Validation loss after epoch 484: 2.9190609455108643
# Validation loss improved! Saving model.
# Validation loss after epoch 485: 2.919086456298828
# Validation loss after epoch 486: 2.9188473224639893
# Validation loss improved! Saving model.
# Validation loss after epoch 487: 2.9186973571777344
# Validation loss improved! Saving model.
# Validation loss after epoch 488: 2.9188644886016846
# Validation loss after epoch 489: 2.91850209236145
# Validation loss improved! Saving model.
# Validation loss after epoch 490: 2.9183523654937744
# Validation loss improved! Saving model.
# Validation loss after epoch 491: 2.9182605743408203
# Validation loss improved! Saving model.
# Validation loss after epoch 492: 2.9180963039398193
# Validation loss improved! Saving model.
# Validation loss after epoch 493: 2.917966365814209
# Validation loss improved! Saving model.
# Validation loss after epoch 494: 2.917792558670044
# Validation loss improved! Saving model.
# Validation loss after epoch 495: 2.917635917663574
# Validation loss improved! Saving model.
# Validation loss after epoch 496: 2.917717695236206
# Validation loss after epoch 497: 2.9174907207489014
# Validation loss improved! Saving model.
# Validation loss after epoch 498: 2.9175429344177246
# Validation loss after epoch 499: 2.9172253608703613
# Validation loss improved! Saving model.
# Validation loss after epoch 500: 2.9172933101654053
# Validation loss after epoch 501: 2.9169962406158447
# Validation loss improved! Saving model.
# Validation loss after epoch 502: 2.9168355464935303
# Validation loss improved! Saving model.
# Validation loss after epoch 503: 2.9168150424957275
# Validation loss improved! Saving model.
# Validation loss after epoch 504: 2.9166486263275146
# Validation loss improved! Saving model.
# Validation loss after epoch 505: 2.9167003631591797
# Validation loss after epoch 506: 2.916513681411743
# Validation loss improved! Saving model.
# Validation loss after epoch 507: 2.916328191757202
# Validation loss improved! Saving model.
# Validation loss after epoch 508: 2.9162466526031494
# Validation loss improved! Saving model.
# Validation loss after epoch 509: 2.9160873889923096
# Validation loss improved! Saving model.
# Validation loss after epoch 510: 2.9157967567443848
# Validation loss improved! Saving model.
# Validation loss after epoch 511: 2.9157955646514893
# Validation loss improved! Saving model.
# Validation loss after epoch 512: 2.915618419647217
# Validation loss improved! Saving model.
# Validation loss after epoch 513: 2.9156360626220703
# Validation loss after epoch 514: 2.915367603302002
# Validation loss improved! Saving model.
# Validation loss after epoch 515: 2.9153215885162354
# Validation loss improved! Saving model.
# Validation loss after epoch 516: 2.9152512550354004
# Validation loss improved! Saving model.
# Validation loss after epoch 517: 2.9152750968933105
# Validation loss after epoch 518: 2.915069103240967
# Validation loss improved! Saving model.
# Validation loss after epoch 519: 2.9149258136749268
# Validation loss improved! Saving model.
# Validation loss after epoch 520: 2.914837121963501
# Validation loss improved! Saving model.
# Validation loss after epoch 521: 2.914630174636841
# Validation loss improved! Saving model.
# Validation loss after epoch 522: 2.9145450592041016
# Validation loss improved! Saving model.
# Validation loss after epoch 523: 2.9144158363342285
# Validation loss improved! Saving model.
# Validation loss after epoch 524: 2.9143118858337402
# Validation loss improved! Saving model.
# Validation loss after epoch 525: 2.9143683910369873
# Validation loss after epoch 526: 2.9141948223114014
# Validation loss improved! Saving model.
# Validation loss after epoch 527: 2.9139857292175293
# Validation loss improved! Saving model.
# Validation loss after epoch 528: 2.9139349460601807
# Validation loss improved! Saving model.
# Validation loss after epoch 529: 2.9139137268066406
# Validation loss improved! Saving model.
# Validation loss after epoch 530: 2.9138810634613037
# Validation loss improved! Saving model.
# Validation loss after epoch 531: 2.913543939590454
# Validation loss improved! Saving model.
# Validation loss after epoch 532: 2.913452625274658
# Validation loss improved! Saving model.
# Validation loss after epoch 533: 2.913374185562134
# Validation loss improved! Saving model.
# Validation loss after epoch 534: 2.9133379459381104
# Validation loss improved! Saving model.
# Validation loss after epoch 535: 2.913219690322876
# Validation loss improved! Saving model.
# Validation loss after epoch 536: 2.913158893585205
# Validation loss improved! Saving model.
# ...
# Validation loss after epoch 1906: 2.79256534576416
# Validation loss improved! Saving model.
# Validation loss after epoch 1907: 2.7925586700439453
# Validation loss improved! Saving model.
# Validation loss after epoch 1908: 2.792604684829712
# Validation loss after epoch 1909: 2.7925479412078857
# Validation loss improved! Saving model.
# Validation loss after epoch 1910: 2.7926025390625
# Validation loss after epoch 1911: 2.7925078868865967
# Validation loss improved! Saving model.
# Validation loss after epoch 1912: 2.792506217956543
# Validation loss improved! Saving model.
# Validation loss after epoch 1913: 2.792510986328125
# Validation loss after epoch 1914: 2.792466640472412
# Validation loss improved! Saving model.
# Validation loss after epoch 1915: 2.7924201488494873
# Validation loss improved! Saving model.
# Validation loss after epoch 1916: 2.792431354522705
# Validation loss after epoch 1917: 2.792428970336914
# Validation loss after epoch 1918: 2.7923641204833984
# Validation loss improved! Saving model.
# Validation loss after epoch 1919: 2.7923872470855713
# Validation loss after epoch 1920: 2.7923812866210938
# Validation loss after epoch 1921: 2.792356491088867
# Validation loss improved! Saving model.
# Validation loss after epoch 1922: 2.792313814163208
# Validation loss improved! Saving model.
# Validation loss after epoch 1923: 2.792318820953369
# Validation loss after epoch 1924: 2.7923200130462646
# Validation loss after epoch 1925: 2.792269706726074
# Validation loss improved! Saving model.
# Validation loss after epoch 1926: 2.792283773422241
# Validation loss after epoch 1927: 2.792264461517334
# Validation loss improved! Saving model.
# Validation loss after epoch 1928: 2.7922658920288086
# Validation loss after epoch 1929: 2.792228937149048
# Validation loss improved! Saving model.
# Validation loss after epoch 1930: 2.7921957969665527
# Validation loss improved! Saving model.
# Validation loss after epoch 1931: 2.79217267036438
# Validation loss improved! Saving model.
# Validation loss after epoch 1932: 2.7921876907348633
# Validation loss after epoch 1933: 2.79217529296875
# Validation loss after epoch 1934: 2.7921500205993652
# Validation loss improved! Saving model.
# Validation loss after epoch 1935: 2.7921230792999268
# Validation loss improved! Saving model.
# Validation loss after epoch 1936: 2.792128324508667
# Validation loss after epoch 1937: 2.792097568511963
# Validation loss improved! Saving model.
# Validation loss after epoch 1938: 2.7920634746551514
# Validation loss improved! Saving model.
# Validation loss after epoch 1939: 2.792105197906494
# Validation loss after epoch 1940: 2.7920427322387695
# Validation loss improved! Saving model.
# Validation loss after epoch 1941: 2.792026996612549
# Validation loss improved! Saving model.
# Validation loss after epoch 1942: 2.7920005321502686
# Validation loss improved! Saving model.
# Validation loss after epoch 1943: 2.791975736618042
# Validation loss improved! Saving model.
# Validation loss after epoch 1944: 2.792018175125122
# Validation loss after epoch 1945: 2.7919869422912598
# Validation loss after epoch 1946: 2.7919247150421143
# Validation loss improved! Saving model.
# Validation loss after epoch 1947: 2.7919178009033203
# Validation loss improved! Saving model.
# Validation loss after epoch 1948: 2.791877269744873
# Validation loss improved! Saving model.
# Validation loss after epoch 1949: 2.79194712638855
# Validation loss after epoch 1950: 2.7918543815612793
# Validation loss improved! Saving model.
# Validation loss after epoch 1951: 2.791820764541626
# Validation loss improved! Saving model.
# Validation loss after epoch 1952: 2.7918179035186768
# Validation loss improved! Saving model.
# Validation loss after epoch 1953: 2.7917885780334473
# Validation loss improved! Saving model.
# Validation loss after epoch 1954: 2.791780710220337
# Validation loss improved! Saving model.
# Validation loss after epoch 1955: 2.791815757751465
# Validation loss after epoch 1956: 2.791785955429077
# Validation loss after epoch 1957: 2.7917227745056152
# Validation loss improved! Saving model.
# Validation loss after epoch 1958: 2.791757822036743
# Validation loss after epoch 1959: 2.7917306423187256
# Validation loss after epoch 1960: 2.7916953563690186
# Validation loss improved! Saving model.
# Validation loss after epoch 1961: 2.791665554046631
# Validation loss improved! Saving model.
# Validation loss after epoch 1962: 2.791656255722046
# Validation loss improved! Saving model.
# Validation loss after epoch 1963: 2.7916364669799805
# Validation loss improved! Saving model.
# Validation loss after epoch 1964: 2.7915902137756348
# Validation loss improved! Saving model.
# Validation loss after epoch 1965: 2.791619300842285
# Validation loss after epoch 1966: 2.7916080951690674
# Validation loss after epoch 1967: 2.7915661334991455
# Validation loss improved! Saving model.
# Validation loss after epoch 1968: 2.7915773391723633
# Validation loss after epoch 1969: 2.7915773391723633
# Validation loss after epoch 1970: 2.7915287017822266
# Validation loss improved! Saving model.
# Validation loss after epoch 1971: 2.7915127277374268
# Validation loss improved! Saving model.
# Validation loss after epoch 1972: 2.7915139198303223
# Validation loss after epoch 1973: 2.791464328765869
# Validation loss improved! Saving model.
# Validation loss after epoch 1974: 2.7914233207702637
# Validation loss improved! Saving model.
# Validation loss after epoch 1975: 2.7914702892303467
# Validation loss after epoch 1976: 2.791412830352783
# Validation loss improved! Saving model.
# Validation loss after epoch 1977: 2.7914063930511475
# Validation loss improved! Saving model.
# Validation loss after epoch 1978: 2.7914464473724365
# Validation loss after epoch 1979: 2.7913978099823
# Validation loss improved! Saving model.
# Validation loss after epoch 1980: 2.791400194168091
# Validation loss after epoch 1981: 2.7913432121276855
# Validation loss improved! Saving model.
# Validation loss after epoch 1982: 2.7913401126861572
# Validation loss improved! Saving model.
# Validation loss after epoch 1983: 2.7913265228271484
# Validation loss improved! Saving model.
# Validation loss after epoch 1984: 2.7912893295288086
# Validation loss improved! Saving model.
# Validation loss after epoch 1985: 2.7912826538085938
# Validation loss improved! Saving model.
# Validation loss after epoch 1986: 2.791276216506958
# Validation loss improved! Saving model.
# Validation loss after epoch 1987: 2.791222333908081
# Validation loss improved! Saving model.
# Validation loss after epoch 1988: 2.7912304401397705
# Validation loss after epoch 1989: 2.7912137508392334
# Validation loss improved! Saving model.
# Validation loss after epoch 1990: 2.791196823120117
# Validation loss improved! Saving model.
# Validation loss after epoch 1991: 2.7911550998687744
# Validation loss improved! Saving model.
# Validation loss after epoch 1992: 2.791170835494995
# Validation loss after epoch 1993: 2.79115891456604
# Validation loss after epoch 1994: 2.7911221981048584
# Validation loss improved! Saving model.
# Validation loss after epoch 1995: 2.79110050201416
# Validation loss improved! Saving model.
# Validation loss after epoch 1996: 2.7911083698272705
# Validation loss after epoch 1997: 2.7910947799682617
# Validation loss improved! Saving model.
# Validation loss after epoch 1998: 2.791076183319092
# Validation loss improved! Saving model.
# Validation loss after epoch 1999: 2.7910518646240234
# Validation loss improved! Saving model.
# Validation loss after epoch 2000: 2.7910754680633545
# Validation loss after epoch 2001: 2.791043996810913
# Validation loss improved! Saving model.
# Validation loss after epoch 2002: 2.7910072803497314
# Validation loss improved! Saving model.
# Validation loss after epoch 2003: 2.790968418121338
# Validation loss improved! Saving model.
# Validation loss after epoch 2004: 2.7909531593322754
# Validation loss improved! Saving model.
# Validation loss after epoch 2005: 2.790938377380371
# Validation loss improved! Saving model.
# Validation loss after epoch 2006: 2.790949821472168
# Validation loss after epoch 2007: 2.790956735610962
# Validation loss after epoch 2008: 2.790930986404419
# Validation loss improved! Saving model.
# Validation loss after epoch 2009: 2.790900230407715
# Validation loss improved! Saving model.
# Validation loss after epoch 2010: 2.790870428085327
# Validation loss improved! Saving model.
# Validation loss after epoch 2011: 2.7908854484558105
# Validation loss after epoch 2012: 2.79085373878479
# Validation loss improved! Saving model.
# Validation loss after epoch 2013: 2.790858507156372
# Validation loss after epoch 2014: 2.7908124923706055
# Validation loss improved! Saving model.
# Validation loss after epoch 2015: 2.790822744369507
# Validation loss after epoch 2016: 2.7908384799957275
# Validation loss after epoch 2017: 2.7908103466033936
# Validation loss improved! Saving model.
# Validation loss after epoch 2018: 2.7908225059509277
# Validation loss after epoch 2019: 2.790817975997925
# Validation loss after epoch 2020: 2.7907822132110596
# Validation loss improved! Saving model.
# Validation loss after epoch 2021: 2.7907631397247314
# Validation loss improved! Saving model.
# Validation loss after epoch 2022: 2.7907679080963135
# Validation loss after epoch 2023: 2.790745496749878
# Validation loss improved! Saving model.
# Validation loss after epoch 2024: 2.7907285690307617
# Validation loss improved! Saving model.
# Validation loss after epoch 2025: 2.79070782661438
# Validation loss improved! Saving model.
# Validation loss after epoch 2026: 2.790693521499634
# Validation loss improved! Saving model.
# Validation loss after epoch 2027: 2.7906806468963623
# Validation loss improved! Saving model.
# Validation loss after epoch 2028: 2.7906534671783447
# Validation loss improved! Saving model.
# Validation loss after epoch 2029: 2.7906579971313477
# Validation loss after epoch 2030: 2.7906417846679688
# Validation loss improved! Saving model.
# Validation loss after epoch 2031: 2.790646553039551
# Validation loss after epoch 2032: 2.790627956390381
# Validation loss improved! Saving model.
# Validation loss after epoch 2033: 2.790584087371826
# Validation loss improved! Saving model.
# Validation loss after epoch 2034: 2.7906322479248047
# Validation loss after epoch 2035: 2.7905499935150146
# Validation loss improved! Saving model.
# Validation loss after epoch 2036: 2.790550470352173
# Validation loss after epoch 2037: 2.7905635833740234
# Validation loss after epoch 2038: 2.7904961109161377
# Validation loss improved! Saving model.
# Validation loss after epoch 2039: 2.7904953956604004
# Validation loss improved! Saving model.
# Validation loss after epoch 2040: 2.7904961109161377
# Validation loss after epoch 2041: 2.790466547012329
# Validation loss improved! Saving model.
# Validation loss after epoch 2042: 2.790445566177368
# Validation loss improved! Saving model.
# Validation loss after epoch 2043: 2.7904534339904785
# Validation loss after epoch 2044: 2.7904207706451416
# Validation loss improved! Saving model.
# Validation loss after epoch 2045: 2.7904324531555176
# Validation loss after epoch 2046: 2.790428638458252
# Validation loss after epoch 2047: 2.7904207706451416
# Validation loss after epoch 2048: 2.790402889251709
# Validation loss improved! Saving model.
# Validation loss after epoch 2049: 2.7903921604156494
# Validation loss improved! Saving model.
# Validation loss after epoch 2050: 2.790381669998169
# Validation loss improved! Saving model.
# Validation loss after epoch 2051: 2.7903878688812256
# Validation loss after epoch 2052: 2.790360450744629
# Validation loss improved! Saving model.
# Validation loss after epoch 2053: 2.790372848510742
# Validation loss after epoch 2054: 2.7903575897216797
# Validation loss improved! Saving model.
# Validation loss after epoch 2055: 2.790330410003662
# Validation loss improved! Saving model.
# Validation loss after epoch 2056: 2.790322780609131
# Validation loss improved! Saving model.
# Validation loss after epoch 2057: 2.790325164794922
# Validation loss after epoch 2058: 2.790316104888916
# Validation loss improved! Saving model.
# Validation loss after epoch 2059: 2.7903056144714355
# Validation loss improved! Saving model.
# Validation loss after epoch 2060: 2.790297746658325
# Validation loss improved! Saving model.
# Validation loss after epoch 2061: 2.7902979850769043
# Validation loss after epoch 2062: 2.7903084754943848
# Validation loss after epoch 2063: 2.7903103828430176
# Validation loss after epoch 2064: 2.790302276611328
# Validation loss after epoch 2065: 2.7902798652648926
# Validation loss improved! Saving model.
# Validation loss after epoch 2066: 2.790269613265991
# Validation loss improved! Saving model.
# Validation loss after epoch 2067: 2.7902684211730957
# Validation loss improved! Saving model.
# Validation loss after epoch 2068: 2.7902400493621826
# Validation loss improved! Saving model.
# Validation loss after epoch 2069: 2.790252923965454
# Validation loss after epoch 2070: 2.7902426719665527
# Validation loss after epoch 2071: 2.790229320526123
# Validation loss improved! Saving model.
# Validation loss after epoch 2072: 2.7902159690856934
# Validation loss improved! Saving model.
# Validation loss after epoch 2073: 2.7902019023895264
# Validation loss improved! Saving model.
# Validation loss after epoch 2074: 2.7902116775512695
# Validation loss after epoch 2075: 2.790186882019043
# Validation loss improved! Saving model.
# Validation loss after epoch 2076: 2.7901806831359863
# Validation loss improved! Saving model.
# Validation loss after epoch 2077: 2.790158748626709
# Validation loss improved! Saving model.
# Validation loss after epoch 2078: 2.7901759147644043
# Validation loss after epoch 2079: 2.7901570796966553
# Validation loss improved! Saving model.
# Validation loss after epoch 2080: 2.7901813983917236
# Validation loss after epoch 2081: 2.790154218673706
# Validation loss improved! Saving model.
# Validation loss after epoch 2082: 2.7901580333709717
# Validation loss after epoch 2083: 2.790144920349121
# Validation loss improved! Saving model.
# Validation loss after epoch 2084: 2.7901201248168945
# Validation loss improved! Saving model.
# Validation loss after epoch 2085: 2.790121078491211
# Validation loss after epoch 2086: 2.79011607170105
# Validation loss improved! Saving model.
# Validation loss after epoch 2087: 2.790127754211426
# Validation loss after epoch 2088: 2.790116786956787
# Validation loss after epoch 2089: 2.7900962829589844
# Validation loss improved! Saving model.
# Validation loss after epoch 2090: 2.790106773376465
# Validation loss after epoch 2091: 2.7901031970977783
# Validation loss after epoch 2092: 2.790086269378662
# Validation loss improved! Saving model.
# Validation loss after epoch 2093: 2.7900753021240234
# Validation loss improved! Saving model.
# Validation loss after epoch 2094: 2.7900640964508057
# Validation loss improved! Saving model.
# Validation loss after epoch 2095: 2.790060520172119
# Validation loss improved! Saving model.
# Validation loss after epoch 2096: 2.790050983428955
# Validation loss improved! Saving model.
# Validation loss after epoch 2097: 2.790062427520752
# Validation loss after epoch 2098: 2.7900571823120117
# Validation loss after epoch 2099: 2.7900452613830566
# Validation loss improved! Saving model.
# Validation loss after epoch 2100: 2.7900402545928955
# Validation loss improved! Saving model.
# Validation loss after epoch 2101: 2.790013313293457
# Validation loss improved! Saving model.
# Validation loss after epoch 2102: 2.79003643989563
# Validation loss after epoch 2103: 2.7900378704071045
# Validation loss after epoch 2104: 2.790015697479248
# Validation loss after epoch 2105: 2.790055513381958
# Validation loss after epoch 2106: 2.7900359630584717
# Validation loss after epoch 2107: 2.790037155151367
# Validation loss after epoch 2108: 2.7900373935699463
# Validation loss after epoch 2109: 2.7900314331054688
# Validation loss after epoch 2110: 2.7900474071502686
# Validation loss after epoch 2111: 2.7900424003601074
# Validation loss after epoch 2112: 2.790034770965576
# Validation loss after epoch 2113: 2.7900171279907227
# Validation loss after epoch 2114: 2.7900230884552
# Validation loss after epoch 2115: 2.790017604827881
# Validation loss after epoch 2116: 2.7900190353393555
# Ran out of patience, early stopping employed!

# %%
model.load_state_dict(torch.load(checkpoint))

# %%
test_loss = get_eval_loss(model, criterion,
                          X_test, Y_test, False)

# %%
test_loss
# Out:
# 317.2533874511719

# %%
test_preds, test_targets = get_eval_preds(model, X_test, Y_test, False)

# %%
test_preds = test_preds.cpu().numpy().flatten()
test_targets = test_targets.cpu().numpy().flatten()

# %%
accuracy = np.isclose(test_preds, test_targets, rtol=1e-4).astype(np.int32).mean()
accuracy
# Out:
# 0.0005

# %%
torch.tanh(model.nac.W_hat)
# Out:
# tensor([[1.0000, 0.9976]], grad_fn=<TanhBackward>)

# %%
torch.sigmoid(model.nac.M_hat)
# Out:
# tensor([[0.9982, 0.9977]], grad_fn=<SigmoidBackward>)

# %%
model.S
# Out:
# Linear(in_features=2, out_features=1, bias=True)

# %%
test_targets[:10]
# Out:
# array([-1218.0051  ,   508.96805 ,   367.82147 ,   851.1205  ,
#          584.9041  ,  -377.07687 , -1888.1703  ,  -505.0698  ,
#         1028.0148  ,    18.078764], dtype=float32)

# %%
test_preds[:10]
# Out:
# array([-1171.1208  ,   491.456   ,   351.11554 ,   811.66907 ,
#          559.27966 ,  -365.16028 ,  1811.9347  ,   486.8439  ,
#          980.87006 ,    17.749733], dtype=float32)

# %%
X_test[:10]
# Out:
# array([[-41.82293364,  29.1229016 ],
#        [ 27.17737426,  18.7276387 ],
#        [-10.57032672, -34.79755119],
#        [-21.88003222, -38.8994161 ],
#        [-32.24733084, -18.13806356],
#        [-44.07634234,   8.55508536],
#        [ 45.73059987, -41.28899055],
#        [ 24.08210651, -20.97282424],
#        [-33.70063163, -30.50431924],
#        [  4.02715109,   4.48921935]])

# %%
Y_test[:5]
# Out:
# array([-1218.00518107,   508.96804602,   367.8214852 ,   851.12047768,
#          584.90413634])
